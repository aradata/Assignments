# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(1, 6):
    for j in range(1, i + 1):
        print("* ", end="")
    print("\r")
for i in range(5, 1, -1):
    for j in range(1, i):
        print("* ", end="")
    print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
strg=input("Input: ")
length = len(strg) 

reverse = strg[length::-1]
print("Output: ", reverse)
# Out:
# Input: ineuron
# Output:  norueni
